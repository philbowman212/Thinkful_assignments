# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
# %matplotlib inline

# %%
df1 = pd.read_csv('denver_crime_8-26-2019.csv')
df2 = pd.read_csv('denver_offense_codes.csv')

# %%
df = df1.merge(df2)

# %%
df.head()
# Out:
#    INCIDENT_ID        OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0   2016376978  2016376978521300          5213                       0
# 1    201872599   201872599521300          5213                       0
# 2    201866465   201866465521300          5213                       0
# 3    201872704   201872704521300          5213                       0
# 4   2018255494  2018255494521300          5213                       0
#
#                 OFFENSE_TYPE_ID OFFENSE_CATEGORY_ID  FIRST_OCCURRENCE_DATE  \
# 0  weapon-unlawful-discharge-of    all-other-crimes  6/15/2016 11:31:00 PM
# 1  weapon-unlawful-discharge-of    all-other-crimes  1/30/2018 10:14:00 PM
# 2  weapon-unlawful-discharge-of    all-other-crimes   1/28/2018 1:30:00 PM
# 3  weapon-unlawful-discharge-of    all-other-crimes  1/30/2018 11:08:00 PM
# 4  weapon-unlawful-discharge-of    all-other-crimes   4/17/2018 2:29:00 AM
#
#    LAST_OCCURRENCE_DATE          REPORTED_DATE  \
# ...

# %%
cdf = pd.DataFrame(index=df.INCIDENT_ID.unique())

# %%
cdf
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
for id in df.INCIDENT_ID:
    value = df.loc[df.INCIDENT_ID == id, 'OFFENSE_CATEGORY_NAME'].values[0]
    cdf.loc[id: value] = 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\philb\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexes\base.py in get_slice_bound(self, label, side, kind)
#    5159             try:
# -> 5160                 return self._searchsorted_monotonic(label, side)
#    5161             except ValueError:
#
# c:\users\philb\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexes\base.py in _searchsorted_monotonic(self, label, side)
#    5120
# -> 5121         raise ValueError("index must be monotonic increasing or decreasing")
#    5122
#
# ValueError: index must be monotonic increasing or decreasing
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-24173b6f802d> in <module>
# ...
